# %% [markdown]
# # 실습: CNN으로 MNIST 분류하기
#
# ## 참고 링크 (검증됨)
# - Kaggle Digit Recognizer (MNIST 손글씨 분류 대회): https://www.kaggle.com/c/digit-recognizer
# - LeetGPU Challenges (conv 커널 연산 연습): https://leetgpu.com/challenges
#
# ## 문제 정의
# - 입력: MNIST 28x28 흑백 손글씨 이미지.
# - 목표: `Conv -> ReLU -> MaxPool` 블록 2개 + FC로 CNN을 구성해 0~9 숫자 10클래스를 분류한다.
# - 출력: epoch별 평균 cost와 테스트 정확도(목표 99% 이상).
#
# ## 학습 포인트
# - flatten 후 `nn.Linear` 입력 차원(`7*7*64`)을 특성 맵 크기와 정확히 맞춘다.
# - 도전: conv 레이어를 하나 더 추가해 정확도가 오르는지 비교한다.

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(777)

learning_rate = 0.001
training_epochs = 15
batch_size = 100

# %%
# TODO: MNIST train/test 데이터셋과 DataLoader 준비
# mnist_train = dsets.MNIST(root='MNIST_data/', train=True, transform=transforms.ToTensor(), download=True)
# mnist_test  = dsets.MNIST(root='MNIST_data/', train=False, transform=transforms.ToTensor(), download=True)
# data_loader = torch.utils.data.DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
# TODO: CNN 모델 정의 (Conv-ReLU-Pool x2 -> Linear(7*7*64, 10))
# class CNN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.layer1 = nn.Sequential(nn.Conv2d(1,32,3,1,1), nn.ReLU(), nn.MaxPool2d(2))
#         self.layer2 = nn.Sequential(nn.Conv2d(32,64,3,1,1), nn.ReLU(), nn.MaxPool2d(2))
#         self.fc = nn.Linear(7*7*64, 10)
#     def forward(self, x):
#         out = self.layer2(self.layer1(x))
#         return self.fc(out.view(out.size(0), -1))
# model = CNN().to(device)

# %%
# TODO: 손실/옵티마이저, 학습 루프, 테스트 정확도
# criterion = nn.CrossEntropyLoss().to(device)
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# for epoch in range(training_epochs):
#     ... zero_grad -> forward -> backward -> step ...
# with torch.no_grad():
#     ... argmax 비교로 정확도 계산 ...
