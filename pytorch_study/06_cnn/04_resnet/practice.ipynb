# %% [markdown]
# # 실습: ResNet으로 이미지 분류하기
#
# ## 참고 링크 (검증됨)
# - Kaggle Dogs vs. Cats (개/고양이 이미지 분류): https://www.kaggle.com/c/dogs-vs-cats
# - Kaggle Digit Recognizer: https://www.kaggle.com/c/digit-recognizer
#
# ## 문제 정의
# - 입력: RGB 이미지(Dogs vs Cats 또는 CIFAR-10).
# - 목표: 잔차 연결(skip connection)을 가진 ResNet을 직접 만들거나 torchvision `resnet18`을 전이학습해 분류한다.
# - 출력: 학습 곡선과 정확도. downsample이 작동하는 블록을 직접 확인한다.
#
# ## 학습 포인트
# - `out += identity` 전에 shape이 맞는지, stride>1/채널 변화 시 downsample이 적용되는지 추적한다.
# - 도전: BasicBlock과 BottleNeck(resnet50)의 파라미터 수/속도를 비교한다.

# %%
import torch
import torch.nn as nn
import torchvision

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %%
# TODO: torchvision 내장 resnet18 불러와 마지막 fc 교체 (전이학습)
# from torchvision import models
# model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
# model.fc = nn.Linear(model.fc.in_features, 2)
# model = model.to(device)

# %%
# TODO: 데이터 변환/로더
# from torchvision import transforms
# trans = transforms.Compose([transforms.Resize((224,224)), transforms.ToTensor()])
# train_data = torchvision.datasets.ImageFolder('dogs_vs_cats/train', transform=trans)
# loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True)

# %%
# TODO: 학습 루프 + 평가
# criterion = nn.CrossEntropyLoss().to(device)
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# ... zero_grad -> forward -> backward -> step ...
