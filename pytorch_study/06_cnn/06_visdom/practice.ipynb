# %% [markdown]
# # 실습: Visdom으로 학습 과정 시각화하기
#
# ## 참고 링크 (검증됨)
# - Visdom 공식 저장소 (설치/사용법): https://github.com/fossasia/visdom
# - 적용 데이터셋 - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/c/digit-recognizer
#
# ## 문제 정의
# - 사전 준비: 터미널에서 `python -m visdom.server` 실행 (기본 http://localhost:8097).
# - 목표: text/image/line 기본 사용법을 익히고, MNIST CNN 학습 루프에 epoch별 loss를 실시간 line plot으로 그린다.
# - 출력: 브라우저 Visdom 대시보드에 갱신되는 loss 곡선.
#
# ## 학습 포인트
# - `update='append'`로 갱신하려면 최초 `vis.line(...)`이 반환한 `win`을 넘겨야 한다.
# - 서버를 먼저 켜지 않으면 `Visdom()` 연결이 실패한다.

# %%
# 사전: 터미널에서 `python -m visdom.server` 실행 후 진행
import torch
import visdom

vis = visdom.Visdom()

# %%
# TODO: 기본 사용법 익히기
# vis.text('Hello World!', env='main')
# vis.image(torch.randn(3, 200, 200))
# vis.images(torch.rand(3, 3, 28, 28))

# %%
# TODO: line plot과 append 갱신
# plt = vis.line(Y=torch.Tensor(1).zero_(), opts=dict(title='loss', legend=['loss'], showlegend=True))
# def loss_tracker(loss_plot, loss_value, num):
#     vis.line(X=num, Y=loss_value, win=loss_plot, update='append')

# %%
# TODO: MNIST CNN 학습 루프 안에서 epoch별 loss를 append
# for epoch in range(training_epochs):
#     ... avg_cost 계산 ...
#     loss_tracker(plt, torch.Tensor([avg_cost]), torch.Tensor([epoch]))
# vis.close(env='main')   # 정리
