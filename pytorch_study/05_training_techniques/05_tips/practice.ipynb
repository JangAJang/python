# %% [markdown]
# # 실습: 학습 종합 팁 (lr / 전처리 / 과적합)
#
# - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/competitions/digit-recognizer
#
# ## 문제 정의
# - 입력: 28x28 MNIST 이미지(또는 표 형식 데이터). 출력: 분류 결과.
# - 목표: (1) learning rate를 크게/작게 바꿔 발산·정체를 관찰하고, (2) 입력을 표준화(평균0/분산1)했을 때 학습이 안정화되는지 비교한다.
# - 과적합 신호(train cost↓ but val cost↑)를 직접 확인하고 regularization으로 완화한다.
#
# ## 학습 포인트
# - train 기준 mu/sigma로 train/test 모두 표준화한다(test로 다시 fit 금지).
# - lr은 가장 먼저 튜닝할 하이퍼파라미터.

# %%
# TODO: import
import torch
import torch.nn.functional as F
import torch.optim as optim

# %%
# TODO: 데이터 로드 자리 (MNIST / Kaggle train.csv)

# %%
# TODO: 표준화 전처리 자리
# mu = x_train.mean(dim=0); sigma = x_train.std(dim=0)
# norm_x_train = (x_train - mu) / sigma

# %%
# TODO: 학습 루프 자리 - lr 여러 값으로 cost 추이 비교
# for lr in [1e-1, 1e-5, 1e1]:
#     optimizer = optim.SGD(model.parameters(), lr=lr)
#     ... cost 발산/정체 관찰
