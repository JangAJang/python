# %% [markdown]
# # 실습: 드롭아웃 (Dropout)
#
# - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/competitions/digit-recognizer
#
# ## 문제 정의
# - 입력: 28x28 MNIST 이미지. 출력: 0~9 클래스.
# - 목표: 깊은 MLP에 nn.Dropout을 넣은 모델과 넣지 않은 모델을 학습해, train/test 정확도 차이(과적합 정도)를 비교한다.
# - model.train() / model.eval() 전환이 결과에 미치는 영향을 확인한다.
#
# ## 학습 포인트
# - dropout은 학습 시에만 켜고 평가 시(model.eval())엔 꺼야 한다.
# - p가 클수록 정규화는 강하지만 학습이 어려워진다(은닉층 0.3~0.5 흔함).

# %%
# TODO: import
import torch
import torch.nn as nn

# %%
# TODO: 데이터 로드 자리 (MNIST / Kaggle train.csv)

# %%
# TODO: 모델 정의 자리 - Dropout 포함
drop = nn.Dropout(p=0.3)
# model = nn.Sequential(linear1, nn.ReLU(), drop, linear2, ...)

# %%
# TODO: 학습 루프 자리
# model.train()  # dropout ON
# ... 학습
# model.eval()   # dropout OFF
# with torch.no_grad(): 평가
