# %% [markdown]
# # 실습: ReLU 활성화 함수와 Optimizer 비교
#
# - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/competitions/digit-recognizer
# - LeetGPU Challenges: https://leetgpu.com/challenges
#
# ## 문제 정의
# - 입력: 28x28 손글씨 숫자 이미지(MNIST). 출력: 0~9 클래스 확률.
# - 목표: 동일한 MLP 구조에서 활성화 함수(Sigmoid/Tanh/ReLU/LeakyReLU)와 optimizer(SGD/Adam 등)를 바꿔가며 학습 손실/정확도를 비교한다.
# - 깊은 망에서 sigmoid가 기울기 소실로 학습이 더딘 것을 ReLU와 비교해 직접 확인한다.
#
# ## 학습 포인트
# - 은닉층 활성화로 ReLU 계열을 쓰면 vanishing gradient가 완화되어 학습이 빠르고 안정적이다.
# - optimizer에 따라 수렴 속도/안정성이 달라진다(잘 모르겠으면 Adam이 무난한 출발점).

# %%
# TODO: import
import torch
import torch.nn as nn
import torch.optim as optim
# import pandas as pd  # Kaggle train.csv 로드용

# %%
# TODO: 데이터 로드 자리
# Kaggle Digit Recognizer의 train.csv를 읽어 X(픽셀/255.), y(label)로 분리
# 또는 torchvision.datasets.MNIST 사용

# %%
# TODO: 모델 정의 자리 - 활성화 함수를 인자로 받는 MLP
class Net(nn.Module):
    def __init__(self, activation):
        super().__init__()
        # TODO: nn.Linear 레이어들과 self.act = activation
        pass
    def forward(self, x):
        # TODO
        return x

# %%
# TODO: 학습 루프 자리 - 활성화/optimizer별로 loss 기록 후 비교
# for name, act in {'Sigmoid':nn.Sigmoid(),'ReLU':nn.ReLU()}.items():
#     model = Net(act); opt = optim.Adam(model.parameters(), lr=0.01)
#     ... 학습 후 손실 곡선 비교
