# %% [markdown]
# # 실습: 가중치 초기화 (Xavier / He)
#
# - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/competitions/digit-recognizer
# - LeetGPU Challenges: https://leetgpu.com/challenges
#
# ## 문제 정의
# - 입력: 28x28 MNIST 이미지. 출력: 0~9 클래스.
# - 목표: 동일한 깊은 MLP를 (1) 기본 초기화, (2) Xavier, (3) He 초기화로 각각 학습해 수렴 속도/최종 정확도를 비교한다.
# - ReLU 망에서 He 초기화가 Xavier/기본보다 유리한지 확인한다.
#
# ## 학습 포인트
# - 활성화에 맞춰 초기화를 고른다: ReLU는 He(kaiming), sigmoid/tanh는 Xavier.
# - 0 초기화는 대칭성 문제로 학습이 안 된다.

# %%
# TODO: import
import torch
import torch.nn as nn

# %%
# TODO: 데이터 로드 자리 (MNIST / Kaggle train.csv)

# %%
# TODO: 레이어 정의 후 초기화 적용 자리
linear = nn.Linear(784, 256)
# Xavier:
# torch.nn.init.xavier_uniform_(linear.weight)
# He(ReLU):
# torch.nn.init.kaiming_normal_(linear.weight, mode='fan_in', nonlinearity='relu')

# %%
# TODO: 학습 루프 자리 - 초기화 방식별 정확도/손실 비교
