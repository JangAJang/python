# %% [markdown]
# # 실습: 배치 정규화 (Batch Normalization)
#
# - Kaggle Digit Recognizer (MNIST): https://www.kaggle.com/competitions/digit-recognizer
#
# ## 문제 정의
# - 입력: 28x28 MNIST 이미지. 출력: 0~9 클래스.
# - 목표: 동일한 MLP를 BatchNorm 유/무로 학습해 수렴 속도와 안정성(특히 다소 큰 learning rate에서)을 비교한다.
# - Linear -> BatchNorm1d -> ReLU 순서로 배치하고 효과를 관찰한다.
#
# ## 학습 포인트
# - BN은 학습 시 배치 통계, 평가 시 누적 통계를 쓰므로 model.train()/eval() 전환 필수.
# - BN을 쓰면 초기화 민감도가 줄고 큰 lr도 비교적 안정적으로 쓸 수 있다.

# %%
# TODO: import
import torch
import torch.nn as nn

# %%
# TODO: 데이터 로드 자리 (MNIST / Kaggle train.csv)

# %%
# TODO: 모델 정의 자리 - BatchNorm1d 포함
# model = nn.Sequential(
#     nn.Linear(784, 256), nn.BatchNorm1d(256), nn.ReLU(),
#     nn.Linear(256, 10))

# %%
# TODO: 학습 루프 자리 - BN 유/무 비교
# model.train() / model.eval() 전환 잊지 말 것
