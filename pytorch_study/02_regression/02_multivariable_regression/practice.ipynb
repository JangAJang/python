# %% [markdown]
# # 실습: 다변수 선형회귀
#
# ## 실습 링크 (검증됨)
# - Kaggle: [House Prices - Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
# - 여러 개의 수치형 feature를 함께 사용해 집값을 예측한다.
#
# ## 문제 정의
# - 입력: 여러 수치 feature (예: `GrLivArea`, `OverallQual`, `GarageCars`, `TotalBsmtSF` 등). 형태 `(m, n)`.
# - 출력: 예측 집값 `SalePrice`. 형태 `(m, 1)`.
# - 목표: `nn.Linear(n, 1)` 모델과 `F.mse_loss`로 다변수 선형회귀를 학습해 여러 특성으로 집값을 예측한다.
#
# ## 학습 포인트
# - feature가 여러 개면 가중치도 여러 개. 행렬곱(`matmul`)/`nn.Linear`로 한 번에 처리한다.
# - feature마다 스케일이 다르므로 각 열을 표준화한 뒤 학습하면 수렴이 안정적이다.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd

# TODO: train.csv 로드 후 사용할 수치 feature 선택
# df = pd.read_csv('train.csv')
# features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF']
# X = df[features].fillna(0).values
# y = df['SalePrice'].values

# %%
# TODO: 텐서 변환 + 열 단위 표준화
# x_train = torch.FloatTensor(X)
# y_train = torch.FloatTensor(y).view(-1, 1)
# x_train = (x_train - x_train.mean(0)) / x_train.std(0)
# y_train = (y_train - y_train.mean()) / y_train.std()

# %%
# TODO: nn.Linear 모델 정의 (입력차원 = feature 개수)
# class MultivariateRegression(nn.Module):
#     def __init__(self, n_features):
#         super().__init__()
#         self.linear = nn.Linear(n_features, 1)
#     def forward(self, x):
#         return self.linear(x)
# model = MultivariateRegression(x_train.shape[1])
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# TODO: 학습 루프
# for epoch in range(2000):
#     prediction = model(x_train)
#     cost = F.mse_loss(prediction, y_train)
#     optimizer.zero_grad()
#     cost.backward()
#     optimizer.step()
#     if epoch % 200 == 0:
#         print(epoch, cost.item())
