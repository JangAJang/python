# %% [markdown]
# # 실습: 단순 선형회귀
#
# ## 실습 링크 (검증됨)
# - Kaggle: [House Prices - Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
# - 단순화를 위해 하나의 feature(`GrLivArea`, 거주면적)만 사용해 집값(`SalePrice`)을 예측한다.
#
# ## 문제 정의
# - 입력: 집의 거주면적 한 가지(`GrLivArea`, 단일 변수 x).
# - 출력: 예측 집값(`SalePrice`, y).
# - 목표: `H(x) = Wx + b` 가설을 세우고 MSE를 비용으로, `torch.optim.SGD`로 W, b를 학습해 면적으로 집값을 예측한다.
#
# ## 학습 포인트
# - 값의 스케일이 크면(면적 수백, 집값 수십만) 학습이 발산하기 쉽다. 입력/출력을 표준화(평균0, 분산1)하면 안정적으로 수렴한다.
# - `optimizer.zero_grad() -> cost.backward() -> optimizer.step()` 3단계를 정확히 지킬 것.

# %%
import torch
import pandas as pd

# TODO: Kaggle House Prices의 train.csv를 내려받아 로드
# df = pd.read_csv('train.csv')
# x = df['GrLivArea'].values  (단일 feature)
# y = df['SalePrice'].values

# %%
# TODO: 텐서로 변환하고 표준화(정규화)
# x_train = torch.FloatTensor(...).view(-1, 1)
# y_train = torch.FloatTensor(...).view(-1, 1)
# x_train = (x_train - x_train.mean()) / x_train.std()
# y_train = (y_train - y_train.mean()) / y_train.std()

# %%
# TODO: W, b 선언 (requires_grad=True), 옵티마이저 정의
# W = torch.zeros(1, requires_grad=True)
# b = torch.zeros(1, requires_grad=True)
# optimizer = torch.optim.SGD([W, b], lr=0.01)

# %%
# TODO: 학습 루프
# for epoch in range(1000):
#     hypothesis = x_train * W + b
#     cost = torch.mean((hypothesis - y_train) ** 2)   # 괄호 위치 주의!
#     optimizer.zero_grad()
#     cost.backward()
#     optimizer.step()
#     if epoch % 100 == 0:
#         print(epoch, W.item(), b.item(), cost.item())
