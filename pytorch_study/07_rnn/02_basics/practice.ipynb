# %% [markdown]
# # 실습: PyTorch RNN 기초 - shape 다루기
#
# ## 참고 링크 (검증됨)
# - Kaggle 텍스트 데이터셋: [Shakespeare plays](https://www.kaggle.com/datasets/kingburrito666/shakespeare-plays)
# - PyTorch 공식 RNN 문서 개념을 따라 직접 텐서 shape을 맞춰본다.
#
# ## 문제 정의
# - 입력: 임의의 시퀀스 텐서 (batch, seq_len, input_size).
# - 출력: `torch.nn.RNN`을 통과시킨 `outputs`와 `hidden`의 shape.
# - 목표: `input_size`/`hidden_size`/`batch_first` 설정에 따라 입출력 shape이 어떻게 바뀌는지 직접 확인한다.
#
# ## 학습 포인트
# - `outputs.shape == (batch, seq_len, hidden_size)` (batch_first=True 기준)임을 확인하자.
# - `hidden.shape == (num_layers, batch, hidden_size)` 임을 확인하자.

# %%
import torch

# TODO: input_size, hidden_size 를 구체적인 정수로 정의
input_size = 4
hidden_size = 2

# %%
# TODO: (batch=1, seq_len=3, input_size) shape 의 임의 입력 텐서 생성
# input_data = torch.randn(1, 3, input_size)
# rnn = torch.nn.RNN(input_size, hidden_size, batch_first=True)

# %%
# TODO: outputs, status = rnn(input_data)
# TODO: print(outputs.shape, status.shape) 로 결과 shape 확인
