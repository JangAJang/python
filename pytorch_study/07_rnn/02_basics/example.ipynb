# %% [markdown]
# # RNN in Pytorch
#
# ![rnn_structure](img/basis.png)

# %%
import torch;

rnn = torch.nn.RNN(input_size, hidden_size);

outputs, _status = rnn(input_data);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch;
# ----> 3 rnn = torch.nn.RNN(input_size, hidden_size);
#       5 outputs, _status = rnn(input_data);
#
# NameError: name 'input_size' is not defined
