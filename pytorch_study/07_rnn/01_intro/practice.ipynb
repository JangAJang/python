# %% [markdown]
# # 실습: RNN 소개 - 시퀀스 다음 글자 예측 감 잡기
#
# ## 참고 링크 (검증됨)
# - Kaggle 텍스트 데이터셋: [Shakespeare plays](https://www.kaggle.com/datasets/kingburrito666/shakespeare-plays)
# - 개념 복습: char-RNN 스타일의 다음 글자 예측
#
# ## 문제 정의
# - 입력: 짧은 문자열 (예: `"hello"`)을 글자 단위 시퀀스로 변환.
# - 출력: 각 시점에서 '다음에 올 글자'를 예측.
# - 목표: RNN이 hidden state를 통해 이전 글자 정보를 다음 시점으로 전달한다는 것을 직접 확인한다.
#
# ## 학습 포인트
# - 같은 글자 `l`이라도 위치에 따라 다음 글자가 달라질 수 있음을 RNN이 어떻게 구분하는지 관찰하자.
# - `torch.nn.RNN`의 출력 shape `(batch, seq_len, hidden_size)`를 직접 찍어보자.

# %%
import torch
import torch.nn as nn
import numpy as np

# TODO: 작은 문자열 하나를 정하고 글자 집합(char_set)을 만들어보자
sample = "hello"

# %%
# TODO: char_set, char_dic(글자->인덱스) 생성
# TODO: one-hot 인코딩으로 입력 X, 라벨 Y(다음 글자) 만들기

# %%
# TODO: rnn = torch.nn.RNN(input_size, hidden_size, batch_first=True)
# TODO: outputs, status = rnn(X) 호출 후 outputs.shape 확인
# TODO: hidden state(status)가 다음 시점으로 어떻게 전달되는지 구조 이해
