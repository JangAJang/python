# %% [markdown]
# # 실습: 긴 시퀀스 Char-RNN
#
# ## 참고 링크 (검증됨)
# - Kaggle 텍스트 데이터셋: [Shakespeare plays](https://www.kaggle.com/datasets/kingburrito666/shakespeare-plays)
# - 긴 텍스트 코퍼스에서 char-RNN으로 다음 글자를 예측하는 고전 실습.
#
# ## 문제 정의
# - 입력: 긴 문장(또는 텍스트 파일 일부)을 길이 N 슬라이딩 윈도우로 잘라 one-hot 시퀀스로 변환.
# - 출력: 각 윈도우에 대해 한 칸 뒤로 밀린 다음 글자 시퀀스.
# - 목표: 2층 RNN + FC layer로 학습하여 예측 문자열이 원문에 수렴하도록 한다.
#
# ## 학습 포인트
# - 윈도우 슬라이싱으로 하나의 문장에서 다수의 학습 샘플을 만드는 방법.
# - `num_layers`로 RNN을 깊게 쌓고 FC layer를 붙이는 구조를 이해하자.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

sentence = "if you want to build a ship, don't drum up people together to collect wood"
# TODO: char_set, char_dic, dic_size, hidden_size, sequence_length, learning_rate 정의

# %%
# TODO: 슬라이딩 윈도우로 x_data, y_data 생성 (y는 한 칸 뒤로 밀림)
# for i in range(0, len(sentence) - sequence_length): ...
# TODO: x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# TODO: X = torch.FloatTensor(x_one_hot); Y = torch.LongTensor(y_data)

# %%
# TODO: Net 클래스 정의 (nn.RNN(num_layers=2) + nn.Linear)
# TODO: CrossEntropyLoss + Adam 으로 학습 루프 작성
# TODO: argmax(dim=2)로 예측 문자열 복원 후 출력
