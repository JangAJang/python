# %% [markdown]
# # 실습: hihello - 다음 글자 예측 학습
#
# ## 참고 링크 (검증됨)
# - Kaggle 텍스트 데이터셋: [Shakespeare plays](https://www.kaggle.com/datasets/kingburrito666/shakespeare-plays)
# - 본 실습은 짧은 문자열로 char-RNN 학습 루프를 직접 돌려본다.
#
# ## 문제 정의
# - 입력: `if you want you` 같은 짧은 문장의 글자 시퀀스를 one-hot으로 인코딩.
# - 출력: 각 시점에서 다음 글자(클래스 인덱스)를 예측.
# - 목표: CrossEntropyLoss + Adam으로 100 epoch 학습하여 예측 문자열이 정답에 수렴하는 것을 확인한다.
#
# ## 학습 포인트
# - `outputs.view(-1, input_size)` 와 `Y.view(-1)` 의 shape을 맞추는 이유를 이해하자.
# - 입력은 FloatTensor(one-hot), 라벨은 LongTensor(인덱스)임을 기억하자.

# %%
import torch
import torch.optim as optim
import numpy as np

sample = "if you want you"
# TODO: char_set = list(set(sample)); char_dic = {c:i for i,c in enumerate(char_set)}

# %%
# TODO: dic_size, input_size, hidden_size, learning_rate 정의
# TODO: sample_idx -> x_data(앞부분), y_data(한 칸 뒤) 만들기
# TODO: x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# TODO: X = torch.FloatTensor(x_one_hot); Y = torch.LongTensor(y_data)

# %%
# TODO: rnn = torch.nn.RNN(input_size, hidden_size, batch_first=True)
# TODO: criterion = torch.nn.CrossEntropyLoss(); optimizer = optim.Adam(rnn.parameters(), learning_rate)
# TODO: for i in range(100): zero_grad -> forward -> loss -> backward -> step
# TODO: argmax(axis=2)로 예측 문자열 복원해서 출력
